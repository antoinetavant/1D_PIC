# %% [markdown]
# # Tests

# %%
from pic.plasma import plasma as pl
from constantes import(me, q,kb,eps_0,mi)
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from plasma import plasma
import functions
from functions import (numba_interp1D, generate_maxw,numba_interp1D_normed,
                       velocity_maxw_flux, numba_return_part_diag)

from imp import reload
reload(functions)
# Out:
# <module 'functions' from '/home/tavant/these/code/1D_PIC/pic/functions.py'>

# %%
Nmax = 500
partsx = np.linspace(1,2,Nmax,dtype='float64')
partV = np.linspace(1,2,Nmax,dtype='float64')
x_j = np.linspace(1,2,100,dtype='float64')
temp_ve = np.linspace(1,2,100,dtype='float64')
dx = x_j[1]
numba_return_part_diag(Nmax,
                    partsx,
                     partV,
                     x_j,
                      temp_ve,
                     dx, power = 0)

numba_return_part_diag.inspect_types()
# Out:
# numba_return_part_diag (int64, array(float64, 1d, A), array(float64, 1d, A), array(float64, 1d, A), array(float64, 1d, A), float64, int64)
# --------------------------------------------------------------------------------
# # File: /home/tavant/these/code/1D_PIC/pic/functions.py
# # --- LINE 52 ---
# # label 0
# #   del $const0.2
#
# @jit('f8[:](i8,f8[:],f8[:],f8[:],f8[:],f8,i8)',nopython=True)
#
# # --- LINE 53 ---
#
# def numba_return_part_diag(Np, partx, partv, tabx, diag, dx, power):
#
#     # --- LINE 54 ---
#
#     """general function for the particle to grid diagnostics"""
#
# # --- LINE 55 ---
#
#
#
#     # --- LINE 56 ---
#     #   Np = arg(0, name=Np)  :: pyobject
#     #   partx = arg(1, name=partx)  :: pyobject
#     #   partv = arg(2, name=partv)  :: pyobject
#     #   tabx = arg(3, name=tabx)  :: pyobject
#     #   diag = arg(4, name=diag)  :: pyobject
#     #   dx = arg(5, name=dx)  :: pyobject
#     #   power = arg(6, name=power)  :: pyobject
# ...

# %%
for k,v in data_dic.items():
    dset = grp.create_dataset(k, data=v)
    dset = v

# %%
f.close()
